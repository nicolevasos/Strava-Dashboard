# %% [markdown]
# # Strava Activities Analysis
#
# This notebook analyzes GPS activity data from Strava to explore workout preferences, performance evolution, and spatial patterns.
#
# We use Python tools such as `pandas`, `geopandas`, `matplotlib`, `seaborn`, and `folium` to visualize and analyze the data.
#
# Here is the documentation of the geopackages:
# 1. Folium: https://python-visualization.github.io/folium/latest/
# 2. Geopandas: https://geopandas.org/en/stable/docs/user_guide.html

# %%
# Import of the packages

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import seaborn as sns

# %% [markdown]
# Once the data is gotten from the Strava API and store in a csv, we can read the data using pandas

# %%
#Upload CSV
ruta_csv = "../LeafletUpdates/nicole_strava.csv"
activities = pd.read_csv(ruta_csv)
activities
# Out:
#      resource_state                          name  distance  moving_time  \
# 0                 2                Afternoon HIIT       0.0         4531
# 1                 2                  Evening HIIT       0.0         3774
# 2                 2  Lunch Ride - Innersbachklamm  102228.0        21805
# 3                 2                 Night Workout       0.0         4233
# 4                 2             Afternoon Workout       0.0         7148
# ..              ...                           ...       ...          ...
# 215               2                  Morning Ride   10296.7         3654
# 216               2                    Lunch Walk    3998.6         3009
# 217               2                   Arbolito 🌲    23473.4         7171
# 218               2       Ricaurte - Agua de Dios   44084.1         6479
# 219               2                  Morning Walk    3670.9         2952
#
#      elapsed_time  total_elevation_gain     type  \
# 0            4531                   0.0  Workout
# 1            3774                   0.0  Workout
# 2           29696                 545.7     Ride
# 3            4233                   0.0  Workout
# 4            7148                   0.0  Workout
# ..            ...                   ...      ...
# 215          3671                 344.1     Ride
# 216          5817                   7.7     Walk
# 217         15255                 452.4     Ride
# 218         11483                 375.5     Ride
# 219          9525                  18.3     Walk
#
#                         sport_type           id            start_date  ...  \
# 0    HighIntensityIntervalTraining  14500223317  2025-05-16T15:44:26Z  ...
# 1    HighIntensityIntervalTraining  14490724599  2025-05-15T16:24:27Z  ...
# 2                             Ride  14480127482  2025-05-14T09:02:05Z  ...
# 3                          Workout  14470958749  2025-05-13T18:38:54Z  ...
# 4                          Workout  14458609248  2025-05-12T15:59:28Z  ...
# ..                             ...          ...                   ...  ...
# 215                           Ride   9244885459  2023-06-10T12:35:28Z  ...
# 216                           Walk   8621748510  2023-02-25T17:39:16Z  ...
# 217                           Ride   8348110863  2023-01-06T11:39:16Z  ...
# 218                           Ride   8344653157  2023-01-05T21:17:54Z  ...
# 219                           Walk   8038559681  2022-10-29T15:02:58Z  ...
#
#     has_kudoed athlete.id  athlete.resource_state        map.id  \
# 0        False  109915717                       1  a14500223317
# 1        False  109915717                       1  a14490724599
# 2        False  109915717                       1  a14480127482
# 3        False  109915717                       1  a14470958749
# 4        False  109915717                       1  a14458609248
# ..         ...        ...                     ...           ...
# 215      False  109915717                       1   a9244885459
# 216      False  109915717                       1   a8621748510
# 217      False  109915717                       1   a8348110863
# 218      False  109915717                       1   a8344653157
# 219      False  109915717                       1   a8038559681
#
#                                   map.summary_polyline  map.resource_state  \
# 0                                                  NaN                   2
# 1                                                  NaN                   2
# 2    oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...                   2
# 3                                                  NaN                   2
# 4                                                  NaN                   2
# ..                                                 ...                 ...
# 215  }ffYlumgMtCh@`@JzBb@l@^FF?NAJW~A{@nEQn@]t@aAbB...                   2
# 216  mf`\f~`cMtCc@rE_@b@AZEFBP?REJCfAITIt@Aj@GdBGdB...                   2
# 217  egfYjumgMhI|Af@XAj@oAtG{@fCqBzCcAj@qFhBoQhNy@f...                   2
# 218  c{eYrwmgMV_@v@wDdBwFdH_RtHeL|RqPkTuIsFeBuQiHgK...                   2
# 219  ir~[ppecM@OKISKa@[QIIA]Yq@]I@IHS\UVCVFZ\n@VVDJ...                   2
#
#      workout_type  average_watts  device_watts  kilojoules
# 0             NaN            NaN           NaN         NaN
# 1             NaN            NaN           NaN         NaN
# 2            10.0           55.9         False      1219.1
# 3             NaN            NaN           NaN         NaN
# 4             NaN            NaN           NaN         NaN
# ..            ...            ...           ...         ...
# 215           NaN           80.1         False       292.8
# 216           NaN            NaN           NaN         NaN
# 217          10.0            NaN         False         NaN
# 218          10.0            NaN         False         NaN
# 219           NaN            NaN           NaN         NaN
#
# [220 rows x 55 columns]

# %% [markdown]
# Then, we can explore the data using the info function from pandas. As a result, we can see that there are 220 records and the DataFrame contains 55 columns. The number of null values per column and the data types are also shown. Furthermore, it's important to check the column names as a single array in order to identify and select the specific information we want to process later.

# %%
#df info
activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 55 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   resource_state                 220 non-null    int64
#  1   name                           220 non-null    object
#  2   distance                       220 non-null    float64
#  3   moving_time                    220 non-null    int64
#  4   elapsed_time                   220 non-null    int64
#  5   total_elevation_gain           220 non-null    float64
#  6   type                           220 non-null    object
#  7   sport_type                     220 non-null    object
#  8   id                             220 non-null    int64
#  9   start_date                     220 non-null    object
#  10  start_date_local               220 non-null    object
#  11  timezone                       220 non-null    object
#  12  utc_offset                     220 non-null    float64
#  13  location_city                  0 non-null      float64
#  14  location_state                 0 non-null      float64
#  15  location_country               0 non-null      float64
#  16  achievement_count              220 non-null    int64
#  17  kudos_count                    220 non-null    int64
#  18  comment_count                  220 non-null    int64
#  19  athlete_count                  220 non-null    int64
#  20  photo_count                    220 non-null    int64
#  21  trainer                        220 non-null    bool
#  22  commute                        220 non-null    bool
#  23  manual                         220 non-null    bool
#  24  private                        220 non-null    bool
#  25  visibility                     220 non-null    object
#  26  flagged                        220 non-null    bool
#  27  gear_id                        0 non-null      float64
#  28  start_latlng                   220 non-null    object
#  29  end_latlng                     220 non-null    object
#  30  average_speed                  220 non-null    float64
#  31  max_speed                      220 non-null    float64
#  32  has_heartrate                  220 non-null    bool
#  33  average_heartrate              203 non-null    float64
#  34  max_heartrate                  203 non-null    float64
#  35  heartrate_opt_out              220 non-null    bool
#  36  display_hide_heartrate_option  220 non-null    bool
#  37  elev_high                      220 non-null    float64
#  38  elev_low                       220 non-null    float64
#  39  upload_id                      220 non-null    int64
#  40  upload_id_str                  220 non-null    int64
#  41  external_id                    220 non-null    object
#  42  from_accepted_tag              220 non-null    bool
#  43  pr_count                       220 non-null    int64
#  44  total_photo_count              220 non-null    int64
#  45  has_kudoed                     220 non-null    bool
#  46  athlete.id                     220 non-null    int64
#  47  athlete.resource_state         220 non-null    int64
#  48  map.id                         220 non-null    object
#  49  map.summary_polyline           106 non-null    object
#  50  map.resource_state             220 non-null    int64
#  51  workout_type                   42 non-null     float64
#  52  average_watts                  46 non-null     float64
#  53  device_watts                   48 non-null     object
#  54  kilojoules                     46 non-null     float64
# dtypes: bool(10), float64(16), int64(16), object(13)
# memory usage: 79.6+ KB

# %%
#df columns
activities.columns
# Out:
# Index(['resource_state', 'name', 'distance', 'moving_time', 'elapsed_time',
#        'total_elevation_gain', 'type', 'sport_type', 'id', 'start_date',
#        'start_date_local', 'timezone', 'utc_offset', 'location_city',
#        'location_state', 'location_country', 'achievement_count',
#        'kudos_count', 'comment_count', 'athlete_count', 'photo_count',
#        'trainer', 'commute', 'manual', 'private', 'visibility', 'flagged',
#        'gear_id', 'start_latlng', 'end_latlng', 'average_speed', 'max_speed',
#        'has_heartrate', 'average_heartrate', 'max_heartrate',
#        'heartrate_opt_out', 'display_hide_heartrate_option', 'elev_high',
#        'elev_low', 'upload_id', 'upload_id_str', 'external_id',
#        'from_accepted_tag', 'pr_count', 'total_photo_count', 'has_kudoed',
#        'athlete.id', 'athlete.resource_state', 'map.id',
#        'map.summary_polyline', 'map.resource_state', 'workout_type',
#        'average_watts', 'device_watts', 'kilojoules'],
#       dtype='object')

# %% [markdown]
# Filter the data to work with a better performance and understanding of the df. Then, the column related with time and hour is mixed, we need to separate it.

# %%
#Create new dataframe with only columns I care about
cols = ['name', 'upload_id', 'type', 'distance', 'moving_time',   
         'average_speed', 'max_speed','total_elevation_gain',
         'start_date_local', 'start_latlng', 'end_latlng', 'map.summary_polyline'
       ]
activities = activities[cols]

# %%
# format of the date and hour
activities = activities.copy()
activities['start_date_local'] = pd.to_datetime(activities['start_date_local'])
activities['start_time'] = activities['start_date_local'].dt.time
activities['start_date_local'] = activities['start_date_local'].dt.date
activities.head(5)
# Out:
#                            name    upload_id     type  distance  moving_time  \
# 0                Afternoon HIIT  15470552955  Workout       0.0         4531
# 1                  Evening HIIT  15460331668  Workout       0.0         3774
# 2  Lunch Ride - Innersbachklamm  15449061470     Ride  102228.0        21805
# 3                 Night Workout  15439339287  Workout       0.0         4233
# 4             Afternoon Workout  15426341743  Workout       0.0         7148
#
#    average_speed  max_speed  total_elevation_gain start_date_local  \
# 0          0.000      0.000                   0.0       2025-05-16
# 1          0.000      0.000                   0.0       2025-05-15
# 2          4.688     18.043                 545.7       2025-05-14
# 3          0.000      0.000                   0.0       2025-05-13
# 4          0.000      0.000                   0.0       2025-05-12
#
#              start_latlng              end_latlng  \
# 0                      []                      []
# 1                      []                      []
# 2  [47.810196, 13.038183]  [47.810232, 13.038135]
# 3                      []                      []
# 4                      []                      []
#
#                                 map.summary_polyline start_time
# 0                                                NaN   17:44:26
# 1                                                NaN   18:24:27
# 2  oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...   11:02:05
# 3                                                NaN   20:38:54
# 4                                                NaN   17:59:28

# %% [markdown]
# To start to work with geographic data, In the next lines the records with null geodata are printed. It's possible to identify there are 114 without registers. It 114 represents $\frac{114}{220} \times 100 \approx 51.82\%$ of the total amount of data.

# %%
# records with null start lanlong
print(activities[activities['start_latlng'].isnull() | activities['start_latlng'].isin(['[]', '', 'None'])])
# Out:
#                              name    upload_id            type  distance  \
# 0                  Afternoon HIIT  15470552955         Workout       0.0
# 1                    Evening HIIT  15460331668         Workout       0.0
# 3                   Night Workout  15439339287         Workout       0.0
# 4               Afternoon Workout  15426341743         Workout       0.0
# 5                  Afternoon HIIT  15415012755         Workout       0.0
# ..                            ...          ...             ...       ...
# 191                Lunch Crossfit  12008937900        Crossfit       0.0
# 192       Morning Weight Training  11996027862  WeightTraining       0.0
# 193  Afternoon Swim at Uniandes 🐐  11987571574            Swim      33.5
# 194              Morning Crossfit  11977681097        Crossfit       0.0
# 196  Afternoon Swim at Uniandes 🐐  11942623045            Swim    1100.0
#
#      moving_time  average_speed  max_speed  total_elevation_gain  \
# 0           4531          0.000      0.000                   0.0
# 1           3774          0.000      0.000                   0.0
# 3           4233          0.000      0.000                   0.0
# 4           7148          0.000      0.000                   0.0
# 5           4312          0.000      0.000                   0.0
# ..           ...            ...        ...                   ...
# 191          219          0.000      0.000                   0.0
# 192          161          0.000      0.000                   0.0
# 193           24          1.396      0.905                   0.0
# 194         4899          0.000      0.000                   0.0
# 196         3406          0.323      5.000                   0.0
#
#     start_date_local start_latlng end_latlng map.summary_polyline start_time
# 0         2025-05-16           []         []                  NaN   17:44:26
# 1         2025-05-15           []         []                  NaN   18:24:27
# 3         2025-05-13           []         []                  NaN   20:38:54
# 4         2025-05-12           []         []                  NaN   17:59:28
# 5         2025-05-11           []         []                  NaN   16:11:18
# ..               ...          ...        ...                  ...        ...
# 191       2024-04-22           []         []                  NaN   11:07:28
# 192       2024-04-20           []         []                  NaN   10:08:38
# 193       2024-04-19           []         []                  NaN   15:01:54
# 194       2024-04-18           []         []                  NaN   06:21:09
# 196       2024-04-12           []         []                  NaN   14:08:57
#
# [114 rows x 13 columns]

# %%
#records with null end lanlong
print(activities[activities['end_latlng'].isnull() | activities['end_latlng'].isin(['[]', '', 'None'])])
# Out:
#                              name    upload_id            type  distance  \
# 0                  Afternoon HIIT  15470552955         Workout       0.0
# 1                    Evening HIIT  15460331668         Workout       0.0
# 3                   Night Workout  15439339287         Workout       0.0
# 4               Afternoon Workout  15426341743         Workout       0.0
# 5                  Afternoon HIIT  15415012755         Workout       0.0
# ..                            ...          ...             ...       ...
# 191                Lunch Crossfit  12008937900        Crossfit       0.0
# 192       Morning Weight Training  11996027862  WeightTraining       0.0
# 193  Afternoon Swim at Uniandes 🐐  11987571574            Swim      33.5
# 194              Morning Crossfit  11977681097        Crossfit       0.0
# 196  Afternoon Swim at Uniandes 🐐  11942623045            Swim    1100.0
#
#      moving_time  average_speed  max_speed  total_elevation_gain  \
# 0           4531          0.000      0.000                   0.0
# 1           3774          0.000      0.000                   0.0
# 3           4233          0.000      0.000                   0.0
# 4           7148          0.000      0.000                   0.0
# 5           4312          0.000      0.000                   0.0
# ..           ...            ...        ...                   ...
# 191          219          0.000      0.000                   0.0
# 192          161          0.000      0.000                   0.0
# 193           24          1.396      0.905                   0.0
# 194         4899          0.000      0.000                   0.0
# 196         3406          0.323      5.000                   0.0
#
#     start_date_local start_latlng end_latlng map.summary_polyline start_time
# 0         2025-05-16           []         []                  NaN   17:44:26
# 1         2025-05-15           []         []                  NaN   18:24:27
# 3         2025-05-13           []         []                  NaN   20:38:54
# 4         2025-05-12           []         []                  NaN   17:59:28
# 5         2025-05-11           []         []                  NaN   16:11:18
# ..               ...          ...        ...                  ...        ...
# 191       2024-04-22           []         []                  NaN   11:07:28
# 192       2024-04-20           []         []                  NaN   10:08:38
# 193       2024-04-19           []         []                  NaN   15:01:54
# 194       2024-04-18           []         []                  NaN   06:21:09
# 196       2024-04-12           []         []                  NaN   14:08:57
#
# [114 rows x 13 columns]

# %% [markdown]
# A function to extract the longitud and latitude is created to be applied using a map in the next lines. Once the function is applied, the df activities shows the columns of latitud and longitude separated.

# %%
def extract_lat_lon(latlng_str):
    try:
        lat, lon = latlng_str.strip('[]').split(',')
        return float(lat), float(lon)
    except:
        return None, None

# %%
activities['start_lat'], activities['start_lon'] = zip(*activities['start_latlng'].map(extract_lat_lon))
activities['end_lat'], activities['end_lon'] = zip(*activities['end_latlng'].map(extract_lat_lon))

# %%
activities
# Out:
#                              name    upload_id     type  distance  \
# 0                  Afternoon HIIT  15470552955  Workout       0.0
# 1                    Evening HIIT  15460331668  Workout       0.0
# 2    Lunch Ride - Innersbachklamm  15449061470     Ride  102228.0
# 3                   Night Workout  15439339287  Workout       0.0
# 4               Afternoon Workout  15426341743  Workout       0.0
# ..                            ...          ...      ...       ...
# 215                  Morning Ride   9917797597     Ride   10296.7
# 216                    Lunch Walk   9255579410     Walk    3998.6
# 217                   Arbolito 🌲    8952619873     Ride   23473.4
# 218       Ricaurte - Agua de Dios   8948754056     Ride   44084.1
# 219                  Morning Walk   8602123097     Walk    3670.9
#
#      moving_time  average_speed  max_speed  total_elevation_gain  \
# 0           4531          0.000      0.000                   0.0
# 1           3774          0.000      0.000                   0.0
# 2          21805          4.688     18.043                 545.7
# 3           4233          0.000      0.000                   0.0
# 4           7148          0.000      0.000                   0.0
# ..           ...            ...        ...                   ...
# 215         3654          2.818      7.982                 344.1
# 216         3009          1.329      1.909                   7.7
# 217         7171          3.273     10.387                 452.4
# 218         6479          6.804     15.073                 375.5
# 219         2952          1.244      2.703                  18.3
#
#     start_date_local                             start_latlng  \
# 0         2025-05-16                                       []
# 1         2025-05-15                                       []
# 2         2025-05-14                   [47.810196, 13.038183]
# 3         2025-05-13                                       []
# 4         2025-05-12                                       []
# ..               ...                                      ...
# 215       2023-06-10  [4.297962170094252, -74.78609061799943]
# 216       2023-02-25                    [4.75921, -74.066105]
# 217       2023-01-06                   [4.297663, -74.784424]
# 218       2023-01-05                   [4.295948, -74.786636]
# 219       2022-10-29                   [4.749332, -74.089201]
#
#                                   end_latlng  \
# 0                                         []
# 1                                         []
# 2                     [47.810232, 13.038135]
# 3                                         []
# 4                                         []
# ..                                       ...
# 215  [4.348327768966556, -74.83286884613335]
# 216                   [4.724326, -74.073518]
# 217                   [4.297661, -74.784449]
# 218                    [4.297545, -74.78435]
# 219                   [4.749291, -74.089532]
#
#                                   map.summary_polyline start_time  start_lat  \
# 0                                                  NaN   17:44:26        NaN
# 1                                                  NaN   18:24:27        NaN
# 2    oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...   11:02:05  47.810196
# 3                                                  NaN   20:38:54        NaN
# 4                                                  NaN   17:59:28        NaN
# ..                                                 ...        ...        ...
# 215  }ffYlumgMtCh@`@JzBb@l@^FF?NAJW~A{@nEQn@]t@aAbB...   07:35:28   4.297962
# 216  mf`\f~`cMtCc@rE_@b@AZEFBP?REJCfAITIt@Aj@GdBGdB...   12:39:16   4.759210
# 217  egfYjumgMhI|Af@XAj@oAtG{@fCqBzCcAj@qFhBoQhNy@f...   06:39:16   4.297663
# 218  c{eYrwmgMV_@v@wDdBwFdH_RtHeL|RqPkTuIsFeBuQiHgK...   16:17:54   4.295948
# 219  ir~[ppecM@OKISKa@[QIIA]Yq@]I@IHS\UVCVFZ\n@VVDJ...   10:02:58   4.749332
#
#      start_lon    end_lat    end_lon
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2    13.038183  47.810232  13.038135
# 3          NaN        NaN        NaN
# 4          NaN        NaN        NaN
# ..         ...        ...        ...
# 215 -74.786091   4.348328 -74.832869
# 216 -74.066105   4.724326 -74.073518
# 217 -74.784424   4.297661 -74.784449
# 218 -74.786636   4.297545 -74.784350
# 219 -74.089201   4.749291 -74.089532
#
# [220 rows x 17 columns]

# %% [markdown]
# The libraries geopandas and shapely are used to create a geodatabase with the data georeferenced.  it is necessary to clean the gdf to keep just the raws which contain latitud and longitude.The gdb final just keep 106 records.

# %%
from shapely.geometry import Point

# Create Point geometries
start_geometry = [Point(xy) for xy in zip(activities['start_lon'], activities['start_lat'])]
end_geometry = [Point(xy) for xy in zip(activities['end_lon'], activities['end_lat'])]

# Create a GeoDataFrame with WGS84 coordinate system
gdf = gpd.GeoDataFrame(activities, geometry=start_geometry, crs="EPSG:4326")

#Delete nan
gdf = gdf.dropna(subset=['start_lat', 'start_lon','end_lat', 'end_lon'])

gdf
# Out:
#                                name    upload_id  type  distance  moving_time  \
# 2      Lunch Ride - Innersbachklamm  15449061470  Ride  102228.0        21805
# 6                    Afternoon Ride  15405126253  Ride   25410.6         5436
# 8        Lunch Ride - Wiestaltausee  15391491264  Ride   47500.6         9612
# 9       Morning Ride - Königssee 🇩🇪  15370066510  Ride   70676.2        14971
# 14   Morning Ride - Waginger See 🇩🇪  15293821114  Ride   75665.7        15721
# ..                              ...          ...   ...       ...          ...
# 215                    Morning Ride   9917797597  Ride   10296.7         3654
# 216                      Lunch Walk   9255579410  Walk    3998.6         3009
# 217                     Arbolito 🌲    8952619873  Ride   23473.4         7171
# 218         Ricaurte - Agua de Dios   8948754056  Ride   44084.1         6479
# 219                    Morning Walk   8602123097  Walk    3670.9         2952
#
#      average_speed  max_speed  total_elevation_gain start_date_local  \
# 2            4.688     18.043                 545.7       2025-05-14
# 6            4.675     10.180                  36.7       2025-05-10
# 8            4.942     10.960                 440.2       2025-05-09
# 9            4.721     11.700                 350.0       2025-05-07
# 14           4.813     13.200                 422.3       2025-04-30
# ..             ...        ...                   ...              ...
# 215          2.818      7.982                 344.1       2023-06-10
# 216          1.329      1.909                   7.7       2023-02-25
# 217          3.273     10.387                 452.4       2023-01-06
# 218          6.804     15.073                 375.5       2023-01-05
# 219          1.244      2.703                  18.3       2022-10-29
#
#                                 start_latlng  \
# 2                     [47.810196, 13.038183]
# 6                     [47.810012, 13.037966]
# 8                     [47.810077, 13.037723]
# 9                     [47.810075, 13.037336]
# 14                    [47.810186, 13.037924]
# ..                                       ...
# 215  [4.297962170094252, -74.78609061799943]
# 216                    [4.75921, -74.066105]
# 217                   [4.297663, -74.784424]
# 218                   [4.295948, -74.786636]
# 219                   [4.749332, -74.089201]
#
#                                   end_latlng  \
# 2                     [47.810232, 13.038135]
# 6                      [47.810545, 13.03853]
# 8                     [47.810784, 13.037866]
# 9                     [47.810325, 13.038629]
# 14                    [47.810239, 13.038488]
# ..                                       ...
# 215  [4.348327768966556, -74.83286884613335]
# 216                   [4.724326, -74.073518]
# 217                   [4.297661, -74.784449]
# 218                    [4.297545, -74.78435]
# 219                   [4.749291, -74.089532]
#
#                                   map.summary_polyline start_time  start_lat  \
# 2    oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...   11:02:05  47.810196
# 6    uuxbHmkqnAj@C`Ag@`@XjDa@dGyAvCeA`CiAtA}@jAkAvB...   16:26:26  47.810012
# 8    yuxbH}jqnAnLcB|J_DnEcD`CgDpCcG~F}PtAuHfA{LnDoR...   11:28:36  47.810077
# 9    euxbHikqnA~U{EpAjHxMcKdDcHpD_P|BiR|Hm]fEwOtIeU...   10:34:10  47.810075
# 14   maybHuaqnAiAh\aDMoD_DcX~S~@bEqJ~ZfB`GqAzAiCuAu...   09:56:00  47.810186
# ..                                                 ...        ...        ...
# 215  }ffYlumgMtCh@`@JzBb@l@^FF?NAJW~A{@nEQn@]t@aAbB...   07:35:28   4.297962
# 216  mf`\f~`cMtCc@rE_@b@AZEFBP?REJCfAITIt@Aj@GdBGdB...   12:39:16   4.759210
# 217  egfYjumgMhI|Af@XAj@oAtG{@fCqBzCcAj@qFhBoQhNy@f...   06:39:16   4.297663
# 218  c{eYrwmgMV_@v@wDdBwFdH_RtHeL|RqPkTuIsFeBuQiHgK...   16:17:54   4.295948
# 219  ir~[ppecM@OKISKa@[QIIA]Yq@]I@IHS\UVCVFZ\n@VVDJ...   10:02:58   4.749332
#
#      start_lon    end_lat    end_lon                   geometry
# 2    13.038183  47.810232  13.038135   POINT (13.03818 47.8102)
# 6    13.037966  47.810545  13.038530  POINT (13.03797 47.81001)
# 8    13.037723  47.810784  13.037866  POINT (13.03772 47.81008)
# 9    13.037336  47.810325  13.038629  POINT (13.03734 47.81008)
# 14   13.037924  47.810239  13.038488  POINT (13.03792 47.81019)
# ..         ...        ...        ...                        ...
# 215 -74.786091   4.348328 -74.832869  POINT (-74.78609 4.29796)
# 216 -74.066105   4.724326 -74.073518   POINT (-74.0661 4.75921)
# 217 -74.784424   4.297661 -74.784449  POINT (-74.78442 4.29766)
# 218 -74.786636   4.297545 -74.784350  POINT (-74.78664 4.29595)
# 219 -74.089201   4.749291 -74.089532   POINT (-74.0892 4.74933)
#
# [106 rows x 18 columns]

# %% [markdown]
# Finally, the library folium is used to show and save in a html file the map with the start points of these activities.

# %%
# Create the folium map
m = folium.Map(location=[0, 0], zoom_start=2)

# Add each activity as a CircleMarker
for _, row in gdf.iterrows():
    folium.CircleMarker(
        location=[row['start_lat'], row['start_lon']],
        radius=5,
        popup=f"{row['name']} ({row['type']})",
        color='blue',
        fill=True,
        fill_opacity=0.7
    ).add_to(m)

for _, row in gdf.iterrows():
    folium.CircleMarker(
        location=[row['end_lat'], row['end_lon']],
        radius=4,
        color='red',
        fill=True,
        fill_opacity=0.6,
        popup='End'
    ).add_to(m)

# Save the map to an HTML file
#m.save('strava_start_points.html')

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a660c6e5b84f28d2dcb2acc0845913c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a660c6e5b84f28d2dcb2acc0845913c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a660c6e5b84f28d2dcb2acc0845913c4 = L.map(
#                 &quot;map_a660c6e5b84f28d2dcb2acc0845913c4&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13c38f0249b364254be4735d45d9b99a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13c38f0249b364254be4735d45d9b99a.addTo(map_a660c6e5b84f28d2dcb2acc0845913c4);
#
#
#             var circle_marker_54579b61cb8a349eaf349046511ce9e9 = L.circleMarker(
#                 [47.810196, 13.038183],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a660c6e5b84f28d2dcb2acc0845913c4);
#
#
#         var popup_e2e97a240a60ea69d2fb2a98892e4f54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8710a5600a5aeb8a67f28dc25ba3e6b = $(`&lt;div id=&quot;html_f8710a5600a5aeb8a67f28dc25ba3e6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Ride - Innersbachklamm (Ride)&lt;/div&gt;`)[0];
#                 popup_e2e97a240a60ea69d2fb2a98892e4f54.setContent(html_f8710a5600a5aeb8a67f28dc25ba3e6b);
#
#
#
#         circle_marker_54579b61cb8a349eaf349046511ce9e9.bindPopup(popup_e2e97a240a60ea69d2fb2a98892e4f54)
#         ;
#
#
#
#
#             var circle_marker_5f2f88aececf8a2ed3be4435cb17ee72 = L.circleMarker(
#                 [47.810012, 13.037966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a660c6e5b84f28d2dcb2acc0845913c4);
#
#
#         var popup_78d678e6046063ded49f335b4364ed75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a2d2ca38abae6e741661bc27edddb4b = $(`&lt;div id=&quot;html_4a2d2ca38abae6e741661bc27edddb4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afternoon Ride (Ride)&lt;/div&gt;`)[0];
#                 popup_78d678e6046063ded49f335b4364ed75.setContent(html_4a2d2ca38abae6e741661bc27edddb4b);
#
#
#
#         circle_marker_5f2f88aececf8a2ed3be4435cb17ee72.bindPopup(popup_78d678e6046063ded49f335b4364ed75)
#         ;
#
#
#
#
#             var circle_marker_fbf9b05e7c7d82f81ee827f717ff2f5c = L.circleMarker(
#                 [47.810077, 13.037723],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a660c6e5b84f28d2dcb2acc0845913c4);
#
#
#         var popup_c7f70283251805bc7cf9a98dcc1ea9a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f8f6ad79ef16fd3b4b7fc222a5c1575 = $(`&lt;div id=&quot;html_7f8f6ad79ef16fd3b4b7fc222a5c1575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Ride - Wiestaltausee (Ride)&lt;/div&gt;`)[0];
#                 popup_c7f70283251805bc7cf9a98dcc1ea9a2.setContent(html_7f8f6ad79ef16fd3b4b7fc222a5c1575);
#
#
#
#         circle_marker_fbf9b05e7c7d82f81ee827f717ff2f5c.bindPopup(popup_c7f70283251805bc7cf9a98dcc1ea9a2)
#         ;
#
#
#
#
#             var circle_marker_2b81b4bebe

# %% [markdown]
# Then it's possible to checked the average speed in the different activities using a leyend which show it. This is linked with the started point of the activity.

# %%
# Clean data
gdf = gdf.dropna(subset=['start_lat', 'start_lon', 'average_speed'])

gdf
# Out:
#                                name    upload_id  type  distance  moving_time  \
# 2      Lunch Ride - Innersbachklamm  15449061470  Ride  102228.0        21805
# 6                    Afternoon Ride  15405126253  Ride   25410.6         5436
# 8        Lunch Ride - Wiestaltausee  15391491264  Ride   47500.6         9612
# 9       Morning Ride - Königssee 🇩🇪  15370066510  Ride   70676.2        14971
# 14   Morning Ride - Waginger See 🇩🇪  15293821114  Ride   75665.7        15721
# ..                              ...          ...   ...       ...          ...
# 215                    Morning Ride   9917797597  Ride   10296.7         3654
# 216                      Lunch Walk   9255579410  Walk    3998.6         3009
# 217                     Arbolito 🌲    8952619873  Ride   23473.4         7171
# 218         Ricaurte - Agua de Dios   8948754056  Ride   44084.1         6479
# 219                    Morning Walk   8602123097  Walk    3670.9         2952
#
#      average_speed  max_speed  total_elevation_gain start_date_local  \
# 2            4.688     18.043                 545.7       2025-05-14
# 6            4.675     10.180                  36.7       2025-05-10
# 8            4.942     10.960                 440.2       2025-05-09
# 9            4.721     11.700                 350.0       2025-05-07
# 14           4.813     13.200                 422.3       2025-04-30
# ..             ...        ...                   ...              ...
# 215          2.818      7.982                 344.1       2023-06-10
# 216          1.329      1.909                   7.7       2023-02-25
# 217          3.273     10.387                 452.4       2023-01-06
# 218          6.804     15.073                 375.5       2023-01-05
# 219          1.244      2.703                  18.3       2022-10-29
#
#                                 start_latlng  \
# 2                     [47.810196, 13.038183]
# 6                     [47.810012, 13.037966]
# 8                     [47.810077, 13.037723]
# 9                     [47.810075, 13.037336]
# 14                    [47.810186, 13.037924]
# ..                                       ...
# 215  [4.297962170094252, -74.78609061799943]
# 216                    [4.75921, -74.066105]
# 217                   [4.297663, -74.784424]
# 218                   [4.295948, -74.786636]
# 219                   [4.749332, -74.089201]
#
#                                   end_latlng  \
# 2                     [47.810232, 13.038135]
# 6                      [47.810545, 13.03853]
# 8                     [47.810784, 13.037866]
# 9                     [47.810325, 13.038629]
# 14                    [47.810239, 13.038488]
# ..                                       ...
# 215  [4.348327768966556, -74.83286884613335]
# 216                   [4.724326, -74.073518]
# 217                   [4.297661, -74.784449]
# 218                    [4.297545, -74.78435]
# 219                   [4.749291, -74.089532]
#
#                                   map.summary_polyline start_time  start_lat  \
# 2    oaybHkcqnAvMdFfBnr@{CZrCh@LbIqE`X~OpMaHzGqPnz@...   11:02:05  47.810196
# 6    uuxbHmkqnAj@C`Ag@`@XjDa@dGyAvCeA`CiAtA}@jAkAvB...   16:26:26  47.810012
# 8    yuxbH}jqnAnLcB|J_DnEcD`CgDpCcG~F}PtAuHfA{LnDoR...   11:28:36  47.810077
# 9    euxbHikqnA~U{EpAjHxMcKdDcHpD_P|BiR|Hm]fEwOtIeU...   10:34:10  47.810075
# 14   maybHuaqnAiAh\aDMoD_DcX~S~@bEqJ~ZfB`GqAzAiCuAu...   09:56:00  47.810186
# ..                                                 ...        ...        ...
# 215  }ffYlumgMtCh@`@JzBb@l@^FF?NAJW~A{@nEQn@]t@aAbB...   07:35:28   4.297962
# 216  mf`\f~`cMtCc@rE_@b@AZEFBP?REJCfAITIt@Aj@GdBGdB...   12:39:16   4.759210
# 217  egfYjumgMhI|Af@XAj@oAtG{@fCqBzCcAj@qFhBoQhNy@f...   06:39:16   4.297663
# 218  c{eYrwmgMV_@v@wDdBwFdH_RtHeL|RqPkTuIsFeBuQiHgK...   16:17:54   4.295948
# 219  ir~[ppecM@OKISKa@[QIIA]Yq@]I@IHS\UVCVFZ\n@VVDJ...   10:02:58   4.749332
#
#      start_lon    end_lat    end_lon                   geometry
# 2    13.038183  47.810232  13.038135   POINT (13.03818 47.8102)
# 6    13.037966  47.810545  13.038530  POINT (13.03797 47.81001)
# 8    13.037723  47.810784  13.037866  POINT (13.03772 47.81008)
# 9    13.037336  47.810325  13.038629  POINT (13.03734 47.81008)
# 14   13.037924  47.810239  13.038488  POINT (13.03792 47.81019)
# ..         ...        ...        ...                        ...
# 215 -74.786091   4.348328 -74.832869  POINT (-74.78609 4.29796)
# 216 -74.066105   4.724326 -74.073518   POINT (-74.0661 4.75921)
# 217 -74.784424   4.297661 -74.784449  POINT (-74.78442 4.29766)
# 218 -74.786636   4.297545 -74.784350  POINT (-74.78664 4.29595)
# 219 -74.089201   4.749291 -74.089532   POINT (-74.0892 4.74933)
#
# [106 rows x 18 columns]

# %%
import branca.colormap as cm

m2 = folium.Map(location=[0, 0], zoom_start=2)

# Create a color scale
speed_colormap = cm.linear.YlGnBu_09.scale(gdf['average_speed'].min(), gdf['average_speed'].max())

# Add markers colored by speed
for _, row in gdf.iterrows():
    folium.CircleMarker(
        location=[row['start_lat'], row['start_lon']],
        radius=5,
        color=speed_colormap(row['average_speed']),
        fill=True,
        fill_opacity=0.7,
        popup=f"{row['name']} ({row['average_speed']:.2f} m/s)"
    ).add_to(m2)

speed_colormap.caption = 'Average Speed (m/s)'
speed_colormap.add_to(m2)

m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bcb2fe285e1409847a32a2b2883e869 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bcb2fe285e1409847a32a2b2883e869&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bcb2fe285e1409847a32a2b2883e869 = L.map(
#                 &quot;map_6bcb2fe285e1409847a32a2b2883e869&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66bb5a910ff6ac119cf63252d47a6d8e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66bb5a910ff6ac119cf63252d47a6d8e.addTo(map_6bcb2fe285e1409847a32a2b2883e869);
#
#
#             var circle_marker_3750c3fcc3270b7459271359c02a7edc = L.circleMarker(
#                 [47.810196, 13.038183],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1d88bcff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1d88bcff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6bcb2fe285e1409847a32a2b2883e869);
#
#
#         var popup_e5296833171562a4599262b8552c96de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a04120b4a0c5fa88a0e23e4da4f8ac52 = $(`&lt;div id=&quot;html_a04120b4a0c5fa88a0e23e4da4f8ac52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Ride - Innersbachklamm (4.69 m/s)&lt;/div&gt;`)[0];
#                 popup_e5296833171562a4599262b8552c96de.setContent(html_a04120b4a0c5fa88a0e23e4da4f8ac52);
#
#
#
#         circle_marker_3750c3fcc3270b7459271359c02a7edc.bindPopup(popup_e5296833171562a4599262b8552c96de)
#         ;
#
#
#
#
#             var circle_marker_f8fe7ca8ced0f2394a3982e86aa4dc2e = L.circleMarker(
#                 [47.810012, 13.037966],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1d89bcff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1d89bcff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6bcb2fe285e1409847a32a2b2883e869);
#
#
#         var popup_48bbab1e420397dd13aea05697e8e206 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_631362bcde5a4e5ea780c62d4ba609c7 = $(`&lt;div id=&quot;html_631362bcde5a4e5ea780c62d4ba609c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afternoon Ride (4.67 m/s)&lt;/div&gt;`)[0];
#                 popup_48bbab1e420397dd13aea05697e8e206.setContent(html_631362bcde5a4e5ea780c62d4ba609c7);
#
#
#
#         circle_marker_f8fe7ca8ced0f2394a3982e86aa4dc2e.bindPopup(popup_48bbab1e420397dd13aea05697e8e206)
#         ;
#
#
#
#
#             var circle_marker_1d6b79cbdde7421d767e4a3d3581177c = L.circleMarker(
#                 [47.810077, 13.037723],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f77b4ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6bcb2fe285e1409847a32a2b2883e869);
#
#
#         var popup_8e2a41277132ba194202cf831bed00d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb38cc8ad3abcf1ff0d5ba8e3f60b5a9 = $(`&lt;div id=&quot;html_bb38cc8ad3abcf1ff0d5ba8e3f60b5a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Ride - Wiestaltausee (4.94 m/s)&lt;/div&gt;`)[0];
#                 popup_8e2a41277132ba194202cf831bed00d3.setContent(html_bb38cc8ad3abcf1ff0d5ba8e3f60b5a9);
#
#
#
#         circle_marker_1d6

# %% [markdown]
# The next step could be map the the routes using the column map.summary_polyline. Also, use the simbology related with the average speed. The integration of type of activity can be also helpful to analyze in a depeer way.
