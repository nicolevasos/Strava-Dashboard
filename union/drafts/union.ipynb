# %% [markdown]
# ## Strava Data Analysis
#
# This notebook join all the analysis made individually for the strava data as a final project for Practice: Software Development(Python) course.

# %%
#Check the functions available in the .py
import strava_analysis
dir(strava_analysis)
# Out:
# ['DBSCAN',
#  'DistanceBand',
#  'G_Local',
#  'HeatMap',
#  'KNN',
#  'KernelDensity',
#  'MarkerCluster',
#  'Moran_Local',
#  'PCA',
#  'Point',
#  'Polygon',
#  'StandardScaler',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add_heatmap_layers',
#  'add_layer_control',
#  'add_legend',
#  'advanced_hotspot_analysis',
#  'cm',
#  'create_activity_locations_plot',
#  'create_base_map',
#  'create_clusters_plot',
#  'create_correlation_heatmap',
#  'create_dashboard_html',
#  'create_distance_speed_scatter',
#  'create_heatmap',
#  'create_heatmap_data',
#  'create_hotspots_plot',
#  'create_interactive_map',
#  'create_performance_distributions_plot',
#  'create_temporal_patterns_plot',
#  'ctx',
#  'datetime',
#  'decode_polyline',
#  'display_html_map_simple',
#  'extract_lat_lon',
#  'folium',
#  'generate_comprehensive_report',
#  'go',
#  'gpd',
#  'load_strava_data',
#  'main_analysis',
#  'make_subplots',
#  'map_activities_colored_by_speed',
#  'map_df',
#  'np',
#  'pd',
#  'pdist',
#  'plot_speed_distribution',
#  'plt',
#  'px',
#  'sns',
#  'spatial_clustering_analysis',
#  'squareform',
#  'stats',
#  'warnings']

# %%
# Import your functions
from strava_analysis import load_strava_data, plot_speed_distribution, extract_lat_lon, map_df, map_activities_colored_by_speed

# %% [markdown]
# ### 1. Load the data
# We use a function `load_strava_data()` that selects relevant columns, parses dates, and removes incomplete rows.

# %%
#Use first function, upload the data
df = load_strava_data("data/nicole_strava.csv")
df.head()
# Out:
# loaded 245 of your raw activities
# processed 124 of your activities with enhanced features
#    resource_state                     name  distance  moving_time  \
# 0               2               Lunch Walk    3577.7         4433
# 1               2             Morning Walk    8080.4         9368
# 2               2        Afternoon Walk 🇨🇿    7417.3         7577
# 4               2               Night Ride   11316.2         2907
# 6               2  Munich to Salzburg 🇩🇪🇦🇹  180945.0        37425
#
#    elapsed_time  total_elevation_gain  type sport_type           id  \
# 0          9352                  83.4  Walk       Walk  14870905732
# 1         79083                  93.4  Walk       Walk  14870905942
# 2         23468                 133.2  Walk       Walk  14853128173
# 4         50246                  30.9  Ride       Ride  14842808101
# 6        168127                1119.6  Ride       Ride  14810343297
#
#              start_date  ... performance_score intensity_score  \
# 0  2025-06-21T09:32:17Z  ...         -0.794184        0.150806
# 1  2025-06-20T08:58:27Z  ...         -0.715566        0.227419
# 2  2025-06-19T12:37:46Z  ...         -0.672117        0.264919
# 4  2025-06-18T06:01:11Z  ...         -0.101645        0.460484
# 6  2025-06-13T17:06:04Z  ...          3.136372        0.944355
#
#                    datetime  hour  day_of_week  month  is_weekend  season  \
# 0 2025-06-21 09:32:17+00:00     9            5      6        True       2
# 1 2025-06-20 08:58:27+00:00     8            4      6       False       2
# 2 2025-06-19 12:37:46+00:00    12            3      6       False       2
# 4 2025-06-18 06:01:11+00:00     6            2      6       False       2
# 6 2025-06-13 17:06:04+00:00    17            4      6       False       2
#
#    distance_category  speed_category
# 0              Short            Slow
# 1             Medium            Slow
# 2             Medium            Slow
# 4             Medium        Moderate
# 6              Ultra        Moderate
#
# [5 rows x 73 columns]

# %% [markdown]
# ### 2. Visualize Speed
# The function `plot_speed_distribution()` compares the average and max speeds using histograms.

# %%
# plot speed distribution
plot_speed_distribution(df)

# %% [markdown]
# ### 3.  Extract latitude and longitude
#
# With `extract_lat_lon()`, we extract in two columns for each couple of coordenates separated information.

# %%
df['start_lat'], df['start_lon'] = zip(*df['start_latlng'].map(extract_lat_lon))
df['end_lat'], df['end_lon'] = zip(*df['end_latlng'].map(extract_lat_lon))
df.head()
# Out:
#    resource_state                     name  distance  moving_time  \
# 0               2               Lunch Walk    3577.7         4433
# 1               2             Morning Walk    8080.4         9368
# 2               2        Afternoon Walk 🇨🇿    7417.3         7577
# 4               2               Night Ride   11316.2         2907
# 6               2  Munich to Salzburg 🇩🇪🇦🇹  180945.0        37425
#
#    elapsed_time  total_elevation_gain  type sport_type           id  \
# 0          9352                  83.4  Walk       Walk  14870905732
# 1         79083                  93.4  Walk       Walk  14870905942
# 2         23468                 133.2  Walk       Walk  14853128173
# 4         50246                  30.9  Ride       Ride  14842808101
# 6        168127                1119.6  Ride       Ride  14810343297
#
#              start_date  ... hour day_of_week  month  is_weekend  season  \
# 0  2025-06-21T09:32:17Z  ...    9           5      6        True       2
# 1  2025-06-20T08:58:27Z  ...    8           4      6       False       2
# 2  2025-06-19T12:37:46Z  ...   12           3      6       False       2
# 4  2025-06-18T06:01:11Z  ...    6           2      6       False       2
# 6  2025-06-13T17:06:04Z  ...   17           4      6       False       2
#
#    distance_category  speed_category  start_lon    end_lat    end_lon
# 0              Short            Slow  14.408040  50.085645  14.404228
# 1             Medium            Slow  14.440817  50.088818  14.430049
# 2             Medium            Slow  14.442733  50.084548  14.448283
# 4             Medium        Moderate  13.081949  47.789500  13.041727
# 6              Ultra        Moderate  11.554858  47.810386  13.038394
#
# [5 rows x 76 columns]

# %% [markdown]
# ### 4. Map the Activity starts and end points
# With `map_df()`, we visualize where each activity began using folium.

# %%
#Show activity start points
fmap = map_df(df)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3abadf1ab28c4567c5941848fdc70239 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3abadf1ab28c4567c5941848fdc70239&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3abadf1ab28c4567c5941848fdc70239 = L.map(
#                 &quot;map_3abadf1ab28c4567c5941848fdc70239&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32dd40582d161548b8424770e68ec7a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_32dd40582d161548b8424770e68ec7a3.addTo(map_3abadf1ab28c4567c5941848fdc70239);
#
#
#             var circle_marker_8e50bd4fc58783d7bf5aa0971820156e = L.circleMarker(
#                 [50.091034, 14.40804],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3abadf1ab28c4567c5941848fdc70239);
#
#
#         var popup_ef9464e85b40f77075f20b289176247f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87a98c8c5c3f888706b90fdcf8f7e6e1 = $(`&lt;div id=&quot;html_87a98c8c5c3f888706b90fdcf8f7e6e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Walk (Walk) - Start&lt;/div&gt;`)[0];
#                 popup_ef9464e85b40f77075f20b289176247f.setContent(html_87a98c8c5c3f888706b90fdcf8f7e6e1);
#
#
#
#         circle_marker_8e50bd4fc58783d7bf5aa0971820156e.bindPopup(popup_ef9464e85b40f77075f20b289176247f)
#         ;
#
#
#
#
#             var circle_marker_f4acbfb264821f9f7be12331b13166fd = L.circleMarker(
#                 [50.085645, 14.404228],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3abadf1ab28c4567c5941848fdc70239);
#
#
#         var popup_8ba5a715eaeffe2872fa58c9e8af5356 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ff2984fd895a446d4bca4d012267d91 = $(`&lt;div id=&quot;html_2ff2984fd895a446d4bca4d012267d91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;End&lt;/div&gt;`)[0];
#                 popup_8ba5a715eaeffe2872fa58c9e8af5356.setContent(html_2ff2984fd895a446d4bca4d012267d91);
#
#
#
#         circle_marker_f4acbfb264821f9f7be12331b13166fd.bindPopup(popup_8ba5a715eaeffe2872fa58c9e8af5356)
#         ;
#
#
#
#
#             var circle_marker_6f17cb643cec5ea702738fab3e3df553 = L.circleMarker(
#                 [50.084863, 14.440817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3abadf1ab28c4567c5941848fdc70239);
#
#
#         var popup_43c10bffe596527d5c3e0805a0ecd081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5deeed23a3a180aa600b7a97db842fdf = $(`&lt;div id=&quot;html_5deeed23a3a180aa600b7a97db842fdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Morning Walk (Walk) - Start&lt;/div&gt;`)[0];
#                 popup_43c10bffe596527d5c3e0805a0ecd081.setContent(html_5deeed23a3a180aa600b7a97db842fdf);
#
#
#
#         circle_marker_6f17cb643cec5ea702738fab3e3df553.bindPopup(popup_43c10bffe596527d5c3e0805a0ecd081)
#         ;
#
#
#
#
#             var circle_marker_5a052b97e3f42bc79990a489d148af6d = L.circleMarker(
#                 [50.088818, 14.430049],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;

# %% [markdown]
# ### 5. Map of average speead start points
# With `map_activities_colored_by_speed()`, we visualize the activity start point color-coded by average speed.

# %%
speed_map = map_activities_colored_by_speed(df)
speed_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_040111b97dd3dfd7bd6470b4489873a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_040111b97dd3dfd7bd6470b4489873a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_040111b97dd3dfd7bd6470b4489873a6 = L.map(
#                 &quot;map_040111b97dd3dfd7bd6470b4489873a6&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08f10e8f0a69eb26d8ca072f66728b14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_08f10e8f0a69eb26d8ca072f66728b14.addTo(map_040111b97dd3dfd7bd6470b4489873a6);
#
#
#             var circle_marker_dd630d9025dfff022d3f2df6b4dc1603 = L.circleMarker(
#                 [50.091034, 14.40804],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffd9ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffffd9ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_040111b97dd3dfd7bd6470b4489873a6);
#
#
#         var popup_a7f3f7b512d30bd3019b77ca51c9acd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e805033557e7750cb0ba2a844b3faa1 = $(`&lt;div id=&quot;html_1e805033557e7750cb0ba2a844b3faa1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lunch Walk (0.81 m/s)&lt;/div&gt;`)[0];
#                 popup_a7f3f7b512d30bd3019b77ca51c9acd6.setContent(html_1e805033557e7750cb0ba2a844b3faa1);
#
#
#
#         circle_marker_dd630d9025dfff022d3f2df6b4dc1603.bindPopup(popup_a7f3f7b512d30bd3019b77ca51c9acd6)
#         ;
#
#
#
#
#             var circle_marker_c6e7f1101e20debbcd761b8fb2b7bcb1 = L.circleMarker(
#                 [50.084863, 14.440817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#feffd6ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#feffd6ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_040111b97dd3dfd7bd6470b4489873a6);
#
#
#         var popup_cc56d5e10daa11db9ba779093a1a8900 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d4a86cf707b300cf4949b913c5b6832 = $(`&lt;div id=&quot;html_9d4a86cf707b300cf4949b913c5b6832&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Morning Walk (0.86 m/s)&lt;/div&gt;`)[0];
#                 popup_cc56d5e10daa11db9ba779093a1a8900.setContent(html_9d4a86cf707b300cf4949b913c5b6832);
#
#
#
#         circle_marker_c6e7f1101e20debbcd761b8fb2b7bcb1.bindPopup(popup_cc56d5e10daa11db9ba779093a1a8900)
#         ;
#
#
#
#
#             var circle_marker_9e77e9e92dae17d590233d63f0727299 = L.circleMarker(
#                 [50.090379, 14.442733],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fbfed0ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fbfed0ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_040111b97dd3dfd7bd6470b4489873a6);
#
#
#         var popup_b4fbb7e6b293846be81acce919cc97eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ce60e78dc8485335b5fe6cc46ca6015 = $(`&lt;div id=&quot;html_1ce60e78dc8485335b5fe6cc46ca6015&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afternoon Walk 🇨🇿 (0.98 m/s)&lt;/div&gt;`)[0];
#                 popup_b4fbb7e6b293846be81acce919cc97eb.setContent(html_1ce60e78dc8485335b5fe6cc46ca6015);
#
#
#
#         circle_marker_9e77e9e92dae17d590233d63f0727299.bindPopup(popup_b4fbb7e6b293846be81acce919cc97eb)
#         ;
#
#
#
#
#             var circle_marker_914d11f9073cc611e577fcea8f686aa2 = L.circleMarker(
#                 [47.777358, 13.081949],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;

# %% [markdown]
# # More geostatistical analysis

# %%
from strava_analysis import (
    load_strava_data,
    advanced_hotspot_analysis,
    spatial_clustering_analysis,
    create_activity_locations_plot,
    create_hotspots_plot,
    create_performance_distributions_plot,
    create_temporal_patterns_plot,
    create_correlation_heatmap,
    create_distance_speed_scatter,
    create_clusters_plot,
    create_interactive_map,
    create_dashboard_html,
    display_html_map_simple,
    generate_comprehensive_report,
    main_analysis
)

# %%
csv_file = "../LeafletUpdates/nicole_strava.csv"

results = main_analysis(csv_file)

gdf, hotspots, clusters = results
print(f"\nQuick summary:")
print(f"• Analyzed {len(gdf):,} activities")
print(f"• Total distance: {gdf['distance_km'].sum():,.0f} km")
print(f"• Average speed: {gdf['speed_kmh'].mean():.1f} km/h")
if clusters is not None and len(clusters) > 0:
    print(f"• found {len(clusters)} spatial clusters")

print("\nall visualizations are now separate files!")
print("interactive map displayed above (if supported)")
print("open strava_dashboard.html for a beautiful overview!")
# Out:
# loaded 245 of your raw activities
# processed 124 of your activities with enhanced features
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
#      hotspots: 4
#      coldspots: 0
#      spatial clusters: 61
#      spatial outliers: 10
#      hotspots: 0
#      coldspots: 0
#      spatial clusters: 72
#      spatial outliers: 12
#      hotspots: 2
#      coldspots: 0
#      spatial clusters: 41
#      spatial outliers: 9
# found 7 clusters with 54 noise points
# Creating interactive map
# saved interactive map: outputs/strava_interactive_map.html
#
# Generating report...
#    saved report: strava_comprehensive_report.txt
#
# Creating dashboard...
#    saved dashboard: strava_dashboard.html
#
# Exporting results as csv
#
# Analysis complete!
#
# generated files:
# • individual visualization PNGs (7 files)
# • strava_interactive_map.html (interactive map)
# • strava_dashboard.html (beautiful dashboard)
# • strava_comprehensive_report.txt (detailed report)
# • strava_enhanced_results.csv (enhanced dataset)
# opening outputs/strava_interactive_map.html...
# <!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_ff52e524849fe6fa57160396d7a6a092 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
# </head>
# <body>
#
#
#                  <h3 align="center" style="font-size:20px; color: #2E8B57; font-family: Arial;">
#                  <b>Strava Activity Analysis Dashboard</b>
#                  </h3>
#
#
#             <div class="folium-map" id="map_ff52e524849fe6fa57160396d7a6a092" ></div>
#
# </body>
# <script>
#
#
#             var map_ff52e524849fe6fa57160396d7a6a092 = L.map(
#                 "map_ff52e524849fe6fa57160396d7a6a092",
#                 {
#                     center: [47.3565305, 13.0374665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d00a6d1d428d9988725629ad1a165754 = L.tileLayer(
#                 "https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
#                 {"attribution": "\u0026copy; \u003ca href=\"https://www.openstreetmap.org/copyright\"\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\"https://carto.com/attributions\"\u003eCARTO\u003c/a\u003e", "detectRetina": false, "maxNativeZoom": 20, "maxZoom": 20, "minZoom": 0, "noWrap": false, "opacity": 1, "subdomains": "abcd", "tms": false}
#             );
#
#
#             tile_layer_d00a6d1d428d9988725629ad1a165754.addTo(map_ff52e524849fe6fa57160396d7a6a092);
#
#
#             var feature_group_fde9fa4ac9fe7e86bb220021d72e7193 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_a59fda8095aeb35bf85799d7133faab7 = L.circleMarker(
#                 [50.091034, 14.40804],
#                 {"bubblingMouseEvents": true, "color": "blue", "dashArray": null, "dashOffset": null, "fill": true, "fillColor": "blue", "fillOpacity": 0.7, "fillRule": "evenodd", "lineCap": "round", "lineJoin": "round", "opacity": 1.0, "radius": 6, "stroke": true, "weight": 3}
#             ).addTo(feature_group_fde9fa4ac9fe7e86bb220021d72e7193);
#
#
#         var popup_2acdab347b9bf5957746852fe973e305 = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_9816b856a2e374950f9d73ecac1cbc3c = $(`<div id="html_9816b856a2e374950f9d73ecac1cbc3c" style="width: 100.0%; height: 100.0%;">             <div style="font-family: Arial; min-width: 200px;">                 <h4 style="margin: 0; color: blue;">Low performance</h4>                 <hr style="margin: 5px 0;">                 <b>Sport:</b> Walk<br>                 <b>Distance:</b> 3.6 km<br>                 <b>Speed:</b> 2.9 km/h<br>                 <b>Elevation:</b> 83 m<br>                 <b>Date:</b> 2025-06-21             </div>             </div>`)[0];
#                 popup_2acdab347b9bf5957746852fe973e305.setContent(html_9816b856a2e374950f9d73ecac1cbc3c);
#
#
#
#         circle_marker_a59fda8095aeb35bf85799d7133faab7.bindPopup(popup_2acdab347b9bf5957746852fe973e305)
#         ;
#
#
#
#
#             var circle_marker_138ceda5c99c2e4723c541bf3025fdc8 = L.circleMarker(
#                 [50.084863, 14.440817],
#                 {"bubblingMouseEvents": true, "color": "blue", "dashArray": null, "dashOffset": null, "fill": true, "fillColor": "blue", "fillOpacity": 0.7, "fillRule": "evenodd", "lineCap": "round", "lineJoin": "round", "opacity": 1.0, "radius": 6, "stroke": true, "weight": 3}
#             ).addTo(feature_group_fde9fa4ac9fe7e86bb220021d72e7193);
#
#
#         var popup_8db68ab356664b3fd0a9776420ae92fd = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_30b7972e3c7f96e9be11cc5f616be4e8 = $(`<div id="html_30b7972e3c7f96e9be11cc5f616be4e8" style="width: 100.0%; height: 100.0%;">             <div style="font-family: Arial; min-width: 200px;">                 <h4 style="margin: 0; color: blue;">Low performance</h4>                 <hr style="margin: 5px 0;">                 <b>Sport:</b> Walk<br>                 <b>Distance:</b> 8.1 km<br>                 <b>Speed:</b> 3.1 km/h<br>                 <b>Elevation:</b> 93 m<br>                 <b>Date:</b> 2025-06-20             </div>             </div>`)[0];
#                 popup_8db68ab356664b3fd0a9776420ae92fd.setContent(html_30b7972e3c7f96e9be11cc5f616be4e8);
#
#
#
#         circle_marker_138ceda5c99c2e4723c541bf3025fdc8.bindPopup(popup_8db68ab356664b3fd0a9776420ae92fd)
#         ;
#
#
#
#
#             var circle_marker_39dd5a4992bb0ccbfdf3890a8c6974e3 = L.circleMarker(
#                 [50.090379, 14.442733],
#                 {"bubblingMouseEvents": true, "color": "blue", "dashArray": null, "dashOffset": null, "fill": true, "fillColor": "blue", "fillOpacity": 0.7, "fillRule": "evenodd", "lineCap": "round", "lineJoin": "round", "opacity": 1.0, "radius": 6, "stroke": true, "weight": 3}
#             ).addTo(feature_group_fde9fa4ac9fe7e86bb220021d72e7193);
#
#
#         var popup_111761556e5eefa243f6948f5b4e3f93 = L.popup({"maxWidth": "100%"});
#
#
#
#                 var html_f2c49df4180074a192c706b30e09c88a = $(`<div id="html_f2c49df4180074a192c706b30e09c88a" style="width: 100.0%; height: 100.0%;">             <div style="font-family: Arial; min-width: 200px;">                 <h4 style="margin: 0; color: blue;">Low performance</h4>                 <hr style="margin: 5px 0;">                 <b>Sport:</b> Walk<br>                 <b>Distance:</b> 7.4 km<br>                 <b>Speed:</b> 3.5 km/h<br>                 <b>Elevation:</b> 133 m<br>                 <b>Date:</b> 2025-06-19             </div>             </div>`)[0];
#                 popup_111761556e5eefa243f6948f5b4e3f93.setContent(html_f2c49df4180074a192c706b30e09c88a);
#
#
#
#         circle_marker_39dd5a4992bb0ccbfdf3890a8c6974e3.bindPopup(popup_111761556e5eefa243f6948f5b4e3f93)
#         ;
#
#
#
#
#             var circle_marker_625530b421d4cd1787815ae88e75b5f8 = L.circleMarker(
#                 [47.777358, 13.081949],
#                 {"bubblingMouseEvents":
#    map displayed successfully!
#    open this file in your browser !
#
# Quick summary:
# • Analyzed 124 activities
# • Total distance: 2,757 km
# • Average speed: 9.4 km/h
# • found 7 spatial clusters
#
# all visualizations are now separate files!
# interactive map displayed above (if supported)
# open strava_dashboard.html for a beautiful overview!

# %%
from IPython.display import HTML
import base64

with open('outputs/strava_interactive_map.html', 'r', encoding='utf-8') as f:
    html_content = f.read()

iframe_html = f'''
<iframe srcdoc="{html_content.replace('"', '&quot;')}"
        width="100%" height="600" frameborder="0">
</iframe>
'''
HTML(iframe_html)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;></script>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_ff52e524849fe6fa57160396d7a6a092 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
# </head>
# <body>
#
#
#                  <h3 align=&quot;center&quot; style=&quot;font-size:20px; color: #2E8B57; font-family: Arial;&quot;>
#                  <b>Strava Activity Analysis Dashboard</b>
#                  </h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_ff52e524849fe6fa57160396d7a6a092&quot; ></div>
#
# </body>
# <script>
#
#
#             var map_ff52e524849fe6fa57160396d7a6a092 = L.map(
#                 &quot;map_ff52e524849fe6fa57160396d7a6a092&quot;,
#                 {
#                     center: [47.3565305, 13.0374665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d00a6d1d428d9988725629ad1a165754 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d00a6d1d428d9988725629ad1a165754.addTo(map_ff52e524849fe6fa57160396d7a6a092);
#
#
#             var feature_group_fde9fa4ac9fe7e86bb220021d72e7193 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_a59fda8095aeb35bf85799d7133faab7 = L.circleMarker(
#                 [50.091034, 14.40804],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_fde9fa4ac9fe7e86bb220021d72e7193);
#
#
#         var popup_2acdab347b9bf5957746852fe973e305 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9816b856a2e374950f9d73ecac1cbc3c = $(`<div id=&quot;html_9816b856a2e374950f9d73ecac1cbc3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;>             <div style=&quot;font-family: Arial; min-width: 200px;&quot;>                 <h4 style=&quot;margin: 0; color: blue;&quot;>Low performance</h4>                 <hr style=&quot;margin: 5px 0;&quot;>                 <b>Sport:</b> Walk<br>                 <b>Distance:</b> 3.6 km<br>                 <b>Speed:</b> 2.9 km/h<br>                 <b>Elevation:</b> 83 m<br>                 <b>Date:</b> 2025-06-21             </div>             </div>`)[0];
#                 popup_2acdab347b9bf5957746852fe973e305.setContent(html_9816b856a2e374950f9d73ecac1cbc3c);
#
#
#
#         circle_marker_a59fda8095aeb35bf85799d7133faab7.bindPopup(popup_2acdab347b9bf5957746852fe973e305)
#         ;
#
#
#
#
#             var circle_marker_138ceda5c99c2e4723c541bf3025fdc8 = L.circleMarker(
#                 [50.084863, 14.440817],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_fde9fa4ac9fe7e86bb220021d72e7193);
#
#
#         var popup_8db68ab356664b3fd0a9776420ae92fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30b7972e3c7f96e9be11cc5f616be4e8 = $(`<div id=&quot;html_30b7972e3c7f96e9be11cc5f616be4e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;>             <div style=&quot;font-family: Arial; min-width: 200px;&quot;>                 <h4 style=&quot;margin: 0; color: blue;&quot;>Low performance</h4>                 <hr style=&quot;margin: 5px 0;&quot;>                 <b>Sport:</b> Walk<br>                 <b>Distance:</b> 8.1 km<br>                 <b>Speed:</b> 3.1 km/h<br>                 <b>Elevation:</b> 93 m<br>                 <b>Date:</b> 2025-06-20             </div>             </div>`)[0];
#                 popup_8db68ab356664b3fd0a9776420ae92fd.setContent(html_30b7972e3c7f96e9be11cc5f616be4e8);
#
#
#
#         circle_marker_138ceda5c99c2e4723c541bf3025fdc8.bindPopup(popup_8db68ab356664b3fd0a9776420ae92fd)
#         ;
#
#
#
#
#             var circle_marker_39dd5a4992bb0ccbfdf3890a8c6974e3 = L.circleMarker(
#                 [50.090379, 14.442733],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_fde9fa4ac9fe7e86bb220021d72e7193);

# %%
with open('outputs/strava_dashboard_aru.html', 'r', encoding='utf-8') as f:
    html_content = f.read()

iframe_html = f'''
<iframe srcdoc="{html_content.replace('"', '&quot;')}"
        width="100%" height="600" frameborder="0">
</iframe>
'''
HTML(iframe_html)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 with open('outputs/strava_dashboard_aru.html', 'r', encoding='utf-8') as f:
#       2     html_content = f.read()
#       4 iframe_html = f'''
#       5 <iframe srcdoc="{html_content.replace('"', '&quot;')}"
#       6         width="100%" height="600" frameborder="0">
#       7 </iframe>
#       8 '''
#
# File ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/strava_dashboard_aru.html'

# %% [markdown]
# # Creation of the speed and frequency heatmap layers
#
# ## Firstly imports packages and functions, and then goes on to configure the map itself.

# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import HeatMap
import polyline
from collections import defaultdict
from strava_analysis import create_heatmap_data, decode_polyline, create_base_map, add_heatmap_layers, add_legend, add_layer_control

# %% [markdown]
# ## Call to the function and create heat map
#
# This section generates an interactive heatmap of the Strava activities using the create_heatmap function. The function reads activity data from a CSV file, decodes the GPS polylines, and computes two types of heatmap layers: one showing the frequency of activity across routes, and another visualizing the average speed along those routes.
#
# The map is currently configured to center over Salzburg, and users can toggle between the speed and  in the map layers.
#
# The final interactive map is saved as an HTML.

# %%
def create_heatmap(csv_file, polyline_column, speed_column, center, zoom, output_file):
    """
    Main function to create the complete heatmap
    """
    # Load data 
    print("Loading CSV...")
    df = pd.read_csv(csv_file)
    print(f"Loaded {len(df)} activities from CSV")
    
    # Process coordinates (using existing create_heatmap_data function)  
    freq_coords, speed_coords = create_heatmap_data(df, polyline_column, speed_column)
    
    if not freq_coords and not speed_coords:
        print("No valid coordinates found. Check your CSV file and columns.")
        return None
    
    # Create map with all components
    m = create_base_map(center, zoom)
    m = add_heatmap_layers(m, freq_coords, speed_coords)
    m = add_legend(m)
    m = add_layer_control(m)
    
    # Save map
    m.save(output_file)
    print(f"Heatmap saved as: {output_file}")
    return m

# Configuration
CSV_FILE = "data/nicole_strava.csv"
POLYLINE_COLUMN = 'map.summary_polyline'
SPEED_COLUMN = 'average_speed'
SALZBURG_CENTER = (47.8095, 13.0550)
ZOOM_LEVEL = 10
OUTPUT_FILE = 'strava_salzburg_heatmap.html'

create_heatmap(CSV_FILE, POLYLINE_COLUMN, SPEED_COLUMN, SALZBURG_CENTER, ZOOM_LEVEL, OUTPUT_FILE)
# Out:
# Loading CSV...
# Loaded 245 activities from CSV
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Processed 100 activities...
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Processed 200 activities...
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Error decoding polyline: name 'polyline' is not defined
# Processed 0 activities with valid polylines
# Total frequency coordinates: 0
# Total speed coordinates: 0
# No valid coordinates found. Check your CSV file and columns.

# %% [markdown]
# # Strava Geographic Route Viewer

# %%
# Import all the functions from the interactive_route_elev.py 
from interactive_route_elev import decode_polyline, plot_route_map, plot_elevation_profile, interactive_dashboard

# install missing packages if needed
import pandas as pd
import polyline

# %% [markdown]
# ## Import the data

# %%
# import and visualize the data
df =pd.read_csv( "data/nicole_strava.csv")

# Filter data by Rides
df_rides = df[df.sport_type == 'Ride']
df_rides.head()
# Out:
#     resource_state                             name  distance  moving_time  \
# 4                2                       Night Ride   11316.2         2907
# 6                2          Munich to Salzburg 🇩🇪🇦🇹  180945.0        37425
# 7                2                   Afternoon Ride   14387.4         3664
# 8                2                     Morning Ride   63252.6        13218
# 11               2  Afternoon Ride - Green Route 🇪🇸   10387.0         2665
#
#     elapsed_time  total_elevation_gain  type sport_type           id  \
# 4          50246                  30.9  Ride       Ride  14842808101
# 6         168127                1119.6  Ride       Ride  14810343297
# 7          16494                 106.2  Ride       Ride  14779160538
# 8          23829                 433.6  Ride       Ride  14765932446
# 11         47587                  36.1  Ride       Ride  14690965913
#
#               start_date  ... has_kudoed athlete.id  athlete.resource_state  \
# 4   2025-06-18T06:01:11Z  ...      False  109915717                       1
# 6   2025-06-13T17:06:04Z  ...      False  109915717                       1
# 7   2025-06-12T13:16:19Z  ...      False  109915717                       1
# 8   2025-06-11T07:12:21Z  ...      False  109915717                       1
# 11  2025-06-03T15:54:56Z  ...      False  109915717                       1
#
#           map.id                               map.summary_polyline  \
# 4   a14842808101  _|rbH}cznA{@_@g@My@Ia@@_AEuAVYNILM\IFO?WUOFKn@...
# 6   a14810343297  kdydHw~oeA|Dqa@XmTd`@aM`EmReQ}`@iAcm@kR}J~LkaA...
# 7   a14779160538  szxbHsbsnAf@uAJo@Zo@vC_Kv@sDQgEYiLa@}Kc@qKsAkR...
# 8   a14765932446  _wxbHgkqnAlC@fScFjEeCzDuExJmWv@UQk@zC}V~H_`@rA...
# 11  a14690965913  {wmsF{jKQYMM}@sAEE[GGEi@eAGGIAGEOU_@o@AQOm@_Cc...
#
#     map.resource_state  workout_type  average_watts  device_watts  kilojoules
# 4                    2           0.0           58.3         False       169.5
# 6                    2          10.0           61.7         False      2310.4
# 7                    2           NaN           63.0         False       231.0
# 8                    2          10.0           64.5         False       852.3
# 11                   2          10.0           38.9         False       103.8
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Select route of interest

# %%
df_rides = df[df.name.str.contains("Munich", case=False, na=False)]
df_rides
# Out:
#    resource_state                     name  distance  moving_time  \
# 6               2  Munich to Salzburg 🇩🇪🇦🇹  180945.0        37425
#
#    elapsed_time  total_elevation_gain  type sport_type           id  \
# 6        168127                1119.6  Ride       Ride  14810343297
#
#              start_date  ... has_kudoed athlete.id  athlete.resource_state  \
# 6  2025-06-13T17:06:04Z  ...      False  109915717                       1
#
#          map.id                               map.summary_polyline  \
# 6  a14810343297  kdydHw~oeA|Dqa@XmTd`@aM`EmReQ}`@iAcm@kR}J~LkaA...
#
#    map.resource_state  workout_type  average_watts  device_watts  kilojoules
# 6                   2          10.0           61.7         False      2310.4
#
# [1 rows x 55 columns]

# %% [markdown]
# ## Visualize the route on the map
# Display the route spatially and the starting and ending point.

# %%
# Decode polyline

polyline_str  = df_rides["map.summary_polyline"].iloc[0]
coords = polyline.decode(polyline_str)

# Display the route map
m = plot_route_map(coords)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_235e8f20a6309ddb43b43d355d3e1ad8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_235e8f20a6309ddb43b43d355d3e1ad8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_235e8f20a6309ddb43b43d355d3e1ad8 = L.map(
#                 &quot;map_235e8f20a6309ddb43b43d355d3e1ad8&quot;,
#                 {
#                     center: [47.86118, 12.24127],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1963ac2a0a9a331806374ce8015c08db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1963ac2a0a9a331806374ce8015c08db.addTo(map_235e8f20a6309ddb43b43d355d3e1ad8);
#
#
#             var poly_line_d85b57b10a0ee82b7d9b9cb091820de3 = L.polyline(
#                 [[48.1391, 11.5558], [48.13815, 11.56133], [48.13802, 11.56476], [48.13271, 11.56701], [48.13174, 11.57012], [48.13465, 11.57555], [48.13502, 11.58293], [48.13812, 11.58484], [48.13588, 11.59546], [48.13212, 11.59767], [48.13168, 11.58851], [48.13381, 11.58905], [48.13626, 11.59315], [48.13568, 11.60638], [48.13302, 11.60742], [48.13153, 11.61164], [48.12469, 11.65416], [48.11945, 11.67114], [48.11764, 11.69002], [48.11295, 11.70148], [48.10256, 11.75219], [48.09184, 11.78334], [48.08809, 11.8006], [48.08421, 11.80901], [48.08281, 11.82414], [48.08919, 11.82836], [48.08955, 11.8303], [48.0914, 11.82988], [48.09218, 11.8236], [48.09141, 11.82979], [48.08977, 11.83157], [48.09021, 11.82939], [48.08864, 11.83102], [48.08886, 11.82831], [48.087, 11.82699], [48.08689, 11.82482], [48.08378, 11.82572], [48.07924, 11.82507], [48.07527, 11.83207], [48.06483, 11.84337], [48.06086, 11.85075], [48.05774, 11.85127], [48.05313, 11.85714], [48.0401, 11.85923], [48.03787, 11.86551], [48.03404, 11.86866], [48.03229, 11.87363], [48.03359, 11.8872], [48.03198, 11.89412], [48.03358, 11.90052], [48.02616, 11.92181], [48.02489, 11.92928], [48.01702, 11.93785], [48.00976, 11.94957], [48.0016, 11.95667], [47.99828, 11.96385], [47.9915, 11.97261], [47.97757, 11.97601], [47.97064, 11.98038], [47.96867, 11.97843], [47.96675, 11.98315], [47.9637, 11.98611], [47.96595, 11.99148], [47.96024, 12.00004], [47.9603, 12.00286], [47.95285, 12.0037], [47.95418, 12.00958], [47.95347, 12.00685], [47.95098, 12.00846], [47.94984, 12.01421], [47.94736, 12.01818], [47.94221, 12.02086], [47.94224, 12.02265], [47.93934, 12.02559], [47.93496, 12.02549], [47.93399, 12.0294], [47.92124, 12.03515], [47.92032, 12.03267], [47.92174, 12.03525], [47.92623, 12.03283], [47.92438, 12.02861], [47.92397, 12.02014], [47.92011, 12.01819], [47.91988, 12.01528], [47.92012, 12.02093], [47.91694, 12.02311], [47.91679, 12.03905], [47.91299, 12.0423], [47.91047, 12.04303], [47.90862, 12.05721], [47.90151, 12.05234], [47.90057, 12.05423], [47.89674, 12.05468], [47.89398, 12.0599], [47.89299, 12.06786], [47.89109, 12.07157], [47.89103, 12.0786], [47.88977, 12.07775], [47.88717, 12.08567], [47.88546, 12.08693], [47.88153, 12.08538], [47.87822, 12.09429], [47.87587, 12.11133], [47.86445, 12.10961], [47.86164, 12.11106], [47.85499, 12.12598], [47.8566, 12.12867], [47.85486, 12.1307], [47.8543, 12.13745], [47.85299, 12.13776], [47.85436, 12.13768], [47.85619, 12.1423], [47.85214, 12.14862], [47.85217, 12.15343], [47.84901, 12.15901], [47.84757, 12.16622], [47.84809, 12.17198], [47.85023, 12.17587], [47.85379, 12.17999], [47.85699, 12.18192], [47.85619, 12.1829], [47.85592, 12.18506], [47.85628, 12.19375], [47.85975, 12.20067], [47.86085, 12.20632], [47.85811, 12.21015], [47.85336, 12.21213], [47.851, 12.22398], [47.85474, 12.22647], [47.85438, 12.22925], [47.85633, 12.22898], [47.85687, 12.23378], [47.85947, 12.23953], [47.86118, 12.24127], [47.86444, 12.23842], [47.85857, 12.24561], [47.85287, 12.24278], [47.85434, 12.24842], [47.85382, 12.25172], [47.85238, 12.25431], [47.85017, 12.25471], [47.84721, 12.26125], [47.8462, 12.27265], [47.84765, 12.27288], [47.85226, 12.28301], [47.85737, 12.28906], [47.85741, 12.29484], [47.86239, 12.3043], [47.86264, 12.31273], [47.85846, 12.31936], [47.8576, 12.32684], [47.8586, 12.33104], [47.85507, 12.33311], [47.85609, 12.33726], [47.85543, 12.34443], [47.84596, 12.34506], [47.84496, 12.34584], [47.84739, 12.34954], [47.84687, 12.3511], [47.83888, 12.35329], [47.83818, 12.35537], [47.83766, 12.35195], [47.8301, 12.3594], [47.82372, 12.36079], [47.81701, 12.37013], [47.81911, 12.37453], [47.81632, 12.38064], [47.81912, 12.38006], [47.82612, 12.38646], [47.82936, 12.38637], [47.83296, 12.3923], [47.83333, 12.41197], [47.83224, 12.41618], [47.8338, 12.41955], [47.8336, 12.43247], [47.83761, 12.45264], [47.83877, 12.47232], [47.84035, 12.47466], [47.83934, 12.48895], [47.85332, 12.48829], [47.85661, 12.48467], [47.8533, 12.48828], [47.83798, 12.49 ...

# %% [markdown]
# ## Retrieve elevation values by coordinate & create cross section
# The elevation values are extracted from an API fetched by every point.

# %%
# Decode polyline
coords = decode_polyline(polyline_str)

# Generate elevation profile
plot_elevation_profile(coords)

# %% [markdown]
# ## Generate interactive dashboard

# %% [markdown]
# Generate an interactive dashboard containing the two previous elements created, a map and a elevation profile.

# %%
interactive_dashboard(coords)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from facets import analyze_activities  
df = analyze_activities(folder="./data/gpx")
# Out:
# Found 46 files to process
# Processing: ./data/gpx\14196646513.gpx
# Processing: ./data/gpx\14508069875.gpx
# Processing: ./data/gpx\14705318029.gpx
# Processing: ./data/gpx\14734920602.gpx
# Processing: ./data/gpx\14734920621.gpx
# Processing: ./data/gpx\14734920633.gpx
# Processing: ./data/gpx\14734920639.gpx
# Processing: ./data/gpx\14734920644.gpx
# Processing: ./data/gpx\14734920650.gpx
# Processing: ./data/gpx\14734920665.gpx
# Processing: ./data/gpx\14734920670.gpx
# Processing: ./data/gpx\14734920677.gpx
# Processing: ./data/gpx\14736586592.gpx
# Processing: ./data/gpx\14736586595.gpx
# Processing: ./data/gpx\14736586614.gpx
# Processing: ./data/gpx\14736586633.gpx
# Processing: ./data/gpx\14736586653.gpx
# Processing: ./data/gpx\14736586659.gpx
# Processing: ./data/gpx\14736586665.gpx
# Processing: ./data/gpx\14736586673.gpx
# Processing: ./data/gpx\14736586681.gpx
# Processing: ./data/gpx\14736586684.gpx
# Processing: ./data/gpx\14736586690.gpx
# Processing: ./data/gpx\14736586698.gpx
# Processing: ./data/gpx\14736586726.gpx
# Processing: ./data/gpx\14736599723.gpx
# Processing: ./data/gpx\14736599750.gpx
# Processing: ./data/gpx\14736599801.gpx
# Processing: ./data/gpx\14736599835.gpx
# Processing: ./data/gpx\14736599856.gpx
# Processing: ./data/gpx\14754940389.gpx
# Processing: ./data/gpx\14790009812.gpx
# Processing: ./data/gpx\14823568557.gpx
# Processing: ./data/gpx\14837652014.gpx
# Processing: ./data/gpx\14846048192.gpx
# Processing: ./data/gpx\14863837898.gpx
# Processing: ./data/gpx\14864450577.gpx
# Processing: ./data/gpx\14995083068.gpx
# Processing: ./data/gpx\15010740804.gpx
# Processing: ./data/gpx\15079308357.gpx
# Processing: ./data/gpx\15180754555.gpx
# Processing: ./data/gpx\15191365185.gpx
# Processing: ./data/gpx\15220185838.gpx
# Processing: ./data/gpx\15301298785.gpx
# Processing: ./data/gpx\15301298801.gpx
# Processing: ./data/gpx\15446288892.gpx
# Successfully processed 193476 data points from 44 activities
